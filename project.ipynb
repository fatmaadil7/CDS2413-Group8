# %% [markdown]
# Fatima Adel: Credit Card Fraud Detection

# %% [markdown]
# Dataset: creditcard.csv

# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# ## Load data set

# %%
dataset = pd.read_csv("Data/creditcard.csv")
dataset.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values
print(X)
print(y)
# Out:
# [[ 0.00000000e+00 -1.35980713e+00 -7.27811733e-02 ...  1.33558377e-01
#   -2.10530535e-02  1.49620000e+02]
#  [ 0.00000000e+00  1.19185711e+00  2.66150712e-01 ... -8.98309914e-03
#    1.47241692e-02  2.69000000e+00]
#  [ 1.00000000e+00 -1.35835406e+00 -1.34016307e+00 ... -5.53527940e-02
#   -5.97518406e-02  3.78660000e+02]
#  ...
#  [ 1.72788000e+05  1.91956501e+00 -3.01253846e-01 ...  4.45477214e-03
#   -2.65608286e-02  6.78800000e+01]
#  [ 1.72788000e+05 -2.40440050e-01  5.30482513e-01 ...  1.08820735e-01
#    1.04532821e-01  1.00000000e+01]
#  [ 1.72792000e+05 -5.33412522e-01 -1.89733337e-01 ... -2.41530880e-03
#    1.36489143e-02  2.17000000e+02]]
# [0 0 0 ... 0 0 0]

# %% [markdown]
# ## Check dataset information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# ## Check for missing values

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# ## Descriptive Statistics Function

# %%
def descriptive_statistics(data, column):
    print("Mean:", data[column].mean())
    print("Median:", data[column].median())
    print("Standard Deviation:", data[column].std())
    print("Minimum:", data[column].min())
    print("Maximum:", data[column].max())

# %% [markdown]
# ## Apply Function on Dependent Variable

# %%
# Apply Function on Dependent Variable
# Dependent variable = Class
descriptive_statistics(df, "Class")
# Out:
# Mean: 0.001727485630620034
# Median: 0.0
# Standard Deviation: 0.0415271896355952
# Minimum: 0
# Maximum: 1

# %% [markdown]
# ## Random Sampling (150)

# %%
random_sample = df.sample(n=150, random_state=1)

descriptive_statistics(random_sample, "Class")
# Out:
# Mean: 0.006666666666666667
# Median: 0.0
# Standard Deviation: 0.08164965809277248
# Minimum: 0
# Maximum: 1

# %% [markdown]
# ## Systematic Sampling

# %%
k = int(len(df) / 150)

systematic_sample = df.iloc[::k]

descriptive_statistics(systematic_sample, "Class")
# Out:
# Mean: 0.0
# Median: 0.0
# Standard Deviation: 0.0
# Minimum: 0
# Maximum: 0

# %% [markdown]
# ## Scatter Plot

# %%
plt.scatter(df["Amount"], df["Class"])
plt.xlabel("Amount")
plt.ylabel("Class")
plt.title("Scatter Plot of Amount vs Class")
plt.show()

# %% [markdown]
# ## Box Plot

# %%
df.boxplot(column="Amount", by="Class")
plt.title("Box Plot of Amount by Class")
plt.suptitle("")
plt.xlabel("Class")
plt.ylabel("Amount")
plt.show()

# %%
## Histogram

# %%
plt.hist(df["Amount"], bins=30)
plt.xlabel("Transaction Amount")
plt.ylabel("Frequency")
plt.title("Histogram of Transaction Amount")
plt.grid(True)

plt.show()

# %%
## Heat Map

# %%
# keep only numeric columns
numeric_df = df.select_dtypes(include=["number"])
# correlation
corr = numeric_df.corr()
# heat map
plt.imshow(corr, cmap="Blues")
plt.colorbar()
plt.title("Correlation Heat Map")
plt.show()

# %%
## Pearson Correlation

# %%
pearson_corr = stats.pearsonr(df["Amount"], df["Class"])
print("Pearson Correlation:", pearson_corr)
# Out:
# Pearson Correlation: PearsonRResult(statistic=np.float64(0.005631753006768619), pvalue=np.float64(0.002651220649191581))

# %%
## Spearman Correlation

# %%
spearman_corr = stats.spearmanr(df["Amount"], df["Class"])
print("Spearman Correlation:", spearman_corr)
# Out:
# Spearman Correlation: SignificanceResult(statistic=np.float64(-0.008338853912812888), pvalue=np.float64(8.575839442748602e-06))

# %%
## Chi-Square Test

# %%
df["Amount_Category"] = pd.cut(df["Amount"], bins=3)

contingency_table = pd.crosstab(df["Amount_Category"], df["Class"])

chi2 = stats.chi2_contingency(contingency_table)

print("Chi-Square Test:", chi2)
# Out:
# Chi-Square Test: Chi2ContingencyResult(statistic=np.float64(0.017305357630194453), pvalue=np.float64(0.9913846478740408), dof=2, expected_freq=array([[2.84305017e+05, 4.91982725e+02],
#        [6.98790760e+00, 1.20923994e-02],
#        [2.99481754e+00, 5.18245689e-03]]))

# %%
## One Sample T-Test

# %%
stats.ttest_1samp(df["Amount"], 100)
# Out:
# TtestResult(statistic=np.float64(-24.85803749738924), pvalue=np.float64(2.9616236526547132e-136), df=np.int64(284806))

# %%
## Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)
print("x_train shape:",X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:",y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# x_train shape: (213605, 30)
# X_test shape: (71202, 30)
# y_train shape: (213605,)
# y_test shape: (71202,)

# %%
## Feature Scaling
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()

X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
## Training the K-NN model on the Training set
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors=7, metric='minkowski', p=2)
classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
## Making the Confusion Matrix
from sklearn.metrics import confusion_matrix, accuracy_score

y_pred = classifier.predict(X_test)

cm = confusion_matrix(y_test, y_pred)
print(cm)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# [[71073     9]
#  [   34    86]]
# Accuracy: 0.9993960843796522

# %%
## Predicting the value
sample = X_test[0:1]

prediction = classifier.predict(sample)
print("Prediction:", prediction)
# Out:
# Prediction: [0]
